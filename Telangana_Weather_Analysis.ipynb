# %% [markdown]
# **Pyspark Installation**

# %%
pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# **Fetching the csv file from S3 bucket**

# %%
import urllib.request

from pathlib import Path

source = "/home/TWD_18_22.csv"
url = "https://pragyanshu-test-s3-bucket.s3.ap-south-1.amazonaws.com/TWD_18_22.csv?response-content-disposition=inline&X-Amz-Security-Token=IQoJb3JpZ2luX2VjED0aCmFwLXNvdXRoLTEiSDBGAiEAgSkiNUAK0jkC3V1fM0YguZgNHuq5rK8AxmvtbszmVN4CIQDVckiWQtKWnl6F6pegQgykkEuDrXNSkRZ%2BqIkduoDDNCr%2FAggWEAEaDDIxNDY1NDM2MTI4NiIMHtxbeBwVB%2BCyXs3pKtwClIB3EVWWbVj6Lq8jKneHZ6I08zbuf4vFQfo%2FHE6pxk0PF2PlW9SB%2B1HjGaE040u%2BJiMkt0MhOqMk%2FFjPsW2VBSzH99GSZAKiPkp789fzQAVoG1IDji4vSWS8Pi%2BbhICwwVqR394ciTn48%2BrphIbs2%2BUL915%2F5Saqhau77KzLoP8vWcmhLsjDfurwQ0REmw8GlGMXUE4d3hql335IzUV00IFutICSvfFBPt56d4Np2Lz0D1Cb%2Fd79pJ2YDElzpILvshDV6P%2FuaXtdffDT3TefFv0KpwbIK4i6Tlhkp8TdqY4fVsyRyaXXEraW0phRitGXhBhqQbUmr%2B%2BMimKZm8uLAaXiVHuJlcZeZ4yks77OGKc46SE9zaIwmD0co45Uq9v8MgacjaZmU6fNzKIUb3uyRLtJH4jSArR0fcRJLPJ3fkOWfGjw1HVb1MPAR2ByE21aE7xYNV7NfhDHEjQkMIaZ5LQGOrICYMLqelITLXCYK9%2Bwvl8%2F3xZEZgTp6U92OayzG4XUBYVSIF5RCPcSeQ82G98koRlizKc3TTOF8fnMWjlCECyKqneWmpxr2oDEwGkGFGPejkX5qNU3EV%2FKSTjR6FWI%2FjennkjIlp68eXdmcuk%2BQX8Liry%2Fodn9y8p9aPiLJHmDEiakMWSeqSJRkGl%2FfjFCnf73xJvgdzMF1BJ7yh7Mf86vo0g%2B%2FwXdjInit3HGZdL2xy5TDCHJtJE5D7IFWjipUqDrQxgvmE5aijr9N%2FbxJ56CrYEpSfEhe43XmI9cKPaBBqHDKNq6Q0y8WVIN3agPT9wlFW7AOwmD%2Fr6%2FF%2Byo9Zl3Tguzl1FuTGn2kuDNbF6Rlnr7ZM7guEAhfGvsr3RiBdj1kLjbtTUk0ROpW0Sz%2BlFKWqAG&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20240718T135516Z&X-Amz-SignedHeaders=host&X-Amz-Expires=60&X-Amz-Credential=ASIATD6TFT3DMENYGHSF%2F20240718%2Fap-south-1%2Fs3%2Faws4_request&X-Amz-Signature=54fbf8a9b5d180f2461a82a97e15cc55fad0582ff52b9650835b11614f54db5e";

sourceFile = Path(source)

if not sourceFile.is_file() :
  urllib.request.urlretrieve(url, source)

# %% [markdown]
# **Application Logic**
# - Loading the csv data into the dataframe.
# - Cleaning and transforming data.
# - Analysing and ranking the data according to its:
#   - Timeline of the data recorded per district and mandal over the years
#   - Rainfall per district and mandal over the years
#   - Worst rainfall per district and mandal over the years
#   - Average of all the factors for a month over the years
#   - Best and worst year for all the factors over the years

# %%
"""
Created on Sat Dec 5
@author: jing0703

Data source:
https://www.metoffice.gov.uk/research/climate/maps-and-data/historic-station-data

Data format:

|district          |mandal|date      |rainfall|temp_min|temp_max|humidity_min|humidity_max|wind_speed_min|wind_speed_max|

|Medchal-Malkajgiri| Uppal|01-01-2018|     0.0|    12.1|    32.6|        23.8|       100.0|           0.0|           6.6|
|Medchal-Malkajgiri| Uppal|02-01-2018|     0.0|    11.6|    32.6|        23.2|       100.0|           0.0|           4.7|
|Medchal-Malkajgiri| Uppal|03-01-2018|     0.0|    13.0|    33.0|        31.5|       100.0|           0.0|           6.3|
|Medchal-Malkajgiri| Uppal|04-01-2018|     0.0|     9.7|    31.7|        27.4|       100.0|           0.0|           5.2|

Step:
1. Load and parse Telangana Weather Station History data
2. Clean and transform data before running the analyzer
3. Summary statistics for Districts and Mandals

Package:
Spark: 3.5.1
Python: 3.10.12
"""

month_list = [
    "JAN",
    "FEB",
    "MAR",
    "APR",
    "MAY",
    "JUN",
    "JUL",
    "AUG",
    "SEPT",
    "OCT",
    "NOV",
    "DEC"
]


def main():
    """
    main function to parse, clean up and analyze data
    """


    print("Program start")
    start_time = timeit.default_timer()
    df_all = spark.read.csv(source, header=True);

    print("Dataframe generated using the csv input:")
    df_all.show()

    date_col = split(df_all["date"], '[-/]')
    df_all = df_all.withColumn("year", date_col.getItem(2)).withColumn("month", date_col.getItem(1)).withColumn("day", date_col.getItem(0));
    df_all.drop('date')

    print("After modifying the dataframe:")
    df_all.show()

    df_all.createOrReplaceTempView("weather_table")

    mandal_list = get_by_mandal_or_district(True)
    district_list = get_by_mandal_or_district()

    print("Districts with data count:")
    district_list.show()
    print("Mandals with data count:")
    mandal_list.show()

    history_rank(df_all)
    history_rank(df_all, "mandal")
    rain_rank(df_all)
    rain_rank(df_all, "mandal")
    worst_rain(df_all)
    worst_rain(df_all, "mandal")
    month_avg(df_all)
    month_avg(df_all, 5)
    best_worst_year_by_month_climate(df_all)
    best_worst_year_by_month_climate(df_all, 9)

    # finish timing program
    end_time = timeit.default_timer()
    print(f"Program duration: {(end_time - start_time)}s")

def get_by_mandal_or_district(get_mandal = False):

    placeHolder = "mandal" if get_mandal else "district"

    result_df = spark.sql(f"""
    SELECT {placeHolder}, COUNT(*) AS row_count
    FROM weather_table
    GROUP BY {placeHolder}
    ORDER BY row_count desc, {placeHolder}
    """)

    return result_df


def round_column(col_names):
    """
    function to round float from multiple columns
    """
    def inner(df):
        for col_name in col_names:
            df = df.withColumn(
                col_name,
                round(df[col_name], 2)
            )
        return df
    return inner



def history_rank(df_complete, group="district"):
    """
    a. Rank mandal by how long they have been online
    """
    print(f"Rank {group} by how long they have been online:")

    # groupby station & get earliest year/ month by agg
    df_online = df_complete.groupBy(group) \
        .agg(
             min("year").alias("online_y"), \
             min("month").alias("online_m"), \
             min("day").alias("online_d") \
         ) \
        .orderBy("online_y", "online_m", "online_d")

    # get dense rank of online time with window and ranking functions
    window = Window.orderBy(asc("online_y"), asc("online_m"), asc("online_d"))

    df_online_rank = df_online.withColumn(
        "online_time_rank",
        dense_rank().over(window)
    )
    limit = 60 if group == "district" else 500

    # showing the resultant df with the online ranking
    df_online_rank.show(limit, truncate = False)



def rain_rank(df_complete, group="district"):
    """
    b. Rank district or mandal by rainfall
    """

    print(f"{group} rank by total rain fall:")
    df_rain = df_complete.groupBy(group) \
                             .agg(
                                 sum("rainfall").alias("total_rainfall")
                             ) \
                             .orderBy("total_rainfall")

    rain_window = Window.orderBy(desc("total_rainfall"))

    df_rain_rank = df_rain.withColumn(
                                    "rainfall_rank",
                                    dense_rank().over(rain_window)
                                 )


    limit = 60 if group == "district" else 500

    # showing the resultant df with the online ranking
    round_column(["total_rainfall"])(df_rain_rank).show(limit, truncate = False)




def worst_rain(df_complete, group="district"):
    """
    c. When was the worst rainfall for each District or mandal

    """
    print(f"Worst rainfall for each {group.capitalize()}:")
    df_worst_rain = df_complete.select([group, "rainfall", "year"])\
                       .groupBy(group, "year") \
                       .agg(
                         sum("rainfall").alias("total_rainfall")
                       ) \
                       .groupBy(group) \
                       .agg(max(struct(col("total_rainfall"), col("year"))).alias("max_rain")) \
                       .select(col(group), col("max_rain.year"), col("max_rain.total_rainfall")) \
                       .orderBy(desc("max_rain.total_rainfall"))

    limit = 60 if group == "district" else 500
    round_column(["total_rainfall"])(df_worst_rain).show(limit, truncate = False)


def month_avg(df_complete, month=7):
    """
    d. What are the averages for any given month across all district or mandal

    """
    print(f"Average for {month_list[month-1]} across all district:")
    df_month_avg = df_complete.where(col("month") == month) \
                            .agg(
                                avg("temp_max").alias("avg_tmax"), \
                                avg("temp_min").alias("avg_tmin"), \
                                avg("humidity_max").alias("avg_hmax"), \
                                avg("humidity_min").alias("avg_hmin"), \
                                avg("wind_speed_max").alias("avg_WSmax"), \
                                avg("wind_speed_min").alias("avg_WSmin"), \
                                avg("rainfall").alias("avg_rain") \
                            )
    round_column(["avg_tmax", "avg_tmin", "avg_hmax",  "avg_hmin", "avg_WSmax", "avg_WSmin", "avg_rain",])(df_month_avg).show(truncate = False)


def best_worst_year_by_month_climate(df_complete, month=7):
    """
    d. what was the best / worst years for a given month across all districts
    """

    currentMonth = month_list[month-1]
    # create df for avg climate of May across all stations and groupby year
    df_may_avg = df_complete.where(col("month") == month) \
                            .groupBy("year") \
                            .agg(
                                avg("temp_max").alias("avg_tmax"), \
                                avg("temp_min").alias("avg_tmin"), \
                                avg("humidity_max").alias("avg_hmax"), \
                                avg("humidity_min").alias("avg_hmin"), \
                                avg("wind_speed_max").alias("avg_WSmax"), \
                                avg("wind_speed_min").alias("avg_WSmin")
                            ) \
                            .orderBy("year").cache()

    # create window by asc & desc for average temp/ af/ sunshine/ rainfall
    tmax_window = Window.orderBy(desc("avg_tmax"))
    tmin_window = Window.orderBy(asc("avg_tmin"))
    af_desc_window = Window.orderBy(desc("avg_hmax"))
    af_asc_window = Window.orderBy(asc("avg_hmin"))
    sun_desc_window = Window.orderBy(desc("avg_WSmax"))
    sun_asc_window = Window.orderBy(asc("avg_WSmin"))
    rain_desc_window = Window.orderBy(desc("avg_rain"))
    rain_asc_window = Window.orderBy(asc("avg_rain"))

    print(f"Best and worst year of temperature for {currentMonth}:")
    newColumn_tmax = f"{month_list[month-1]}_temp_max"
    may_tmax = df_may_avg.withColumn(
                            "tmax_rank",
                            dense_rank().over(tmax_window)
                          ).select("year", "avg_tmax") \
                          .filter(col("tmax_rank") == 1) \
                          .withColumnRenamed("avg_tmax", newColumn_tmax) \
                          .withColumn(newColumn_tmax, round(newColumn_tmax, 2)) \
                          .show()

    newColumn_tmin = f"{month_list[month-1]}_temp_min"
    may_tmin = df_may_avg.withColumn(
                                "tmin_rank",
                                dense_rank().over(tmin_window)
                              ).select("year", "avg_tmin") \
                              .filter(col("tmin_rank") == 1) \
                              .withColumnRenamed("avg_tmin", newColumn_tmin) \
                              .withColumn(newColumn_tmin, round(newColumn_tmin, 2)) \
                              .show()


    print(f"Best and worst year of humidity for {currentMonth}:")
    newColumn_tmax = f"{month_list[month-1]}_humidity_max"
    may_tmax = df_may_avg.withColumn(
                            "hmax_rank",
                            dense_rank().over(tmax_window)
                          ).select("year", "avg_hmax") \
                          .filter(col("hmax_rank") == 1) \
                          .withColumnRenamed("avg_hmax", newColumn_tmax) \
                          .withColumn(newColumn_tmax, round(newColumn_tmax, 2)) \
                          .show()

    newColumn_tmin = f"{month_list[month-1]}_humidity_min"
    may_tmin = df_may_avg.withColumn(
                                "hmin_rank",
                                dense_rank().over(tmin_window)
                              ).select("year", "avg_hmin") \
                              .filter(col("hmin_rank") == 1) \
                              .withColumnRenamed("avg_hmin", newColumn_tmin) \
                              .withColumn(newColumn_tmin, round(newColumn_tmin, 2)) \
                              .show()

    print(f"Best and worst year of wind speed for {currentMonth}:")
    newColumn_tmax = f"{month_list[month-1]}_wind_speed_max"
    may_tmax = df_may_avg.withColumn(
                            "wsmax_rank",
                            dense_rank().over(tmax_window)
                          ).select("year", "avg_wsmax") \
                          .filter(col("wsmax_rank") == 1) \
                          .withColumnRenamed("avg_wsmax", newColumn_tmax) \
                          .withColumn(newColumn_tmax, round(newColumn_tmax, 2)) \
                          .show()

    newColumn_tmin = f"{month_list[month-1]}_wind_speed_min"
    may_tmin = df_may_avg.withColumn(
                                "wsmin_rank",
                                dense_rank().over(tmin_window)
                              ).select("year", "avg_wsmin") \
                              .filter(col("wsmin_rank") == 1) \
                              .withColumnRenamed("avg_wsmin", newColumn_tmin) \
                              .withColumn(newColumn_tmin, round(newColumn_tmin, 2)) \
                              .show()

# %% [markdown]
# **Runner Code**

# %%
if __name__ == '__main__':
    from pyspark import SparkContext, SparkFiles
    from pyspark.conf import SparkConf
    from pyspark.sql import SparkSession, SQLContext, DataFrame
    from pyspark.sql.functions import *
    from pyspark.sql.types import *
    from pyspark.sql.window import Window
    from functools import reduce
    import timeit

    # define Spark configration
    conf = SparkConf().setAppName("Spark Temp App")

    # define Spark driver session
    spark = SparkSession \
            .builder.master("local[*]") \
            .config(conf = conf) \
            .appName("ClimateAnalysis") \
            .getOrCreate()

    sc = spark.sparkContext
    sc.setLogLevel("ERROR")

    main()
# Out:
# Program start
# Dataframe generated using the csv input:
# +------------------+------+----------+--------+--------+--------+------------+------------+--------------+--------------+
# |          district|mandal|      date|rainfall|temp_min|temp_max|humidity_min|humidity_max|wind_speed_min|wind_speed_max|
# +------------------+------+----------+--------+--------+--------+------------+------------+--------------+--------------+
# |Medchal-Malkajgiri| Uppal|01-01-2018|     0.0|    12.1|    32.6|        23.8|       100.0|           0.0|           6.6|
# |Medchal-Malkajgiri| Uppal|02-01-2018|     0.0|    11.6|    32.6|        23.2|       100.0|           0.0|           4.7|
# |Medchal-Malkajgiri| Uppal|03-01-2018|     0.0|    13.0|    33.0|        31.5|       100.0|           0.0|           6.3|
# |Medchal-Malkajgiri| Uppal|04-01-2018|     0.0|     9.7|    31.7|        27.4|       100.0|           0.0|           5.2|
# |Medchal-Malkajgiri| Uppal|05-01-2018|     0.0|     8.8|    31.0|        28.6|       100.0|           0.0|           7.1|
# |Medchal-Malkajgiri| Uppal|06-01-2018|     0.0|     8.7|    31.8|        22.0|       100.0|           0.0|           4.5|
# |Medchal-Malkajgiri| Uppal|07-01-2018|     0.0|     9.2|    31.6|        21.4|       100.0|           0.0|           3.7|
# |Medchal-Malkajgiri| Uppal|08-01-2018|     0.0|     9.6|   31.59|        23.8|       100.0|           0.0|           7.1|
# |Medchal-Malkajgiri| Uppal|09-01-2018|     0.0|    10.5|    30.4|        26.5|       100.0|           0.0|           6.1|
# |Medchal-Malkajgiri| Uppal|10-01-2018|     0.0|    10.8|    30.0|        35.7|       100.0|           0.0|           6.4|
# |Medchal-Malkajgiri| Uppal|11-01-2018|     0.0|    11.8|    32.4|        34.0|       100.0|           0.0|           6.2|
# |Medchal-Malkajgiri| Uppal|12-01-2018|     0.0|    11.8|    34.5|        30.7|       100.0|           0.0|           6.8|
# |Medchal-Malkajgiri| Uppal|13-01-2018|     0.0|    11.7|    34.6|        21.1|       100.0|           0.0|           7.6|
# |Medchal-Malkajgiri| Uppal|14-01-2018|     0.0|    11.4|    34.9|        18.6|        92.8|           0.0|           4.5|
# |Medchal-Malkajgiri| Uppal|15-01-2018|     0.0|    14.3|    34.4|        25.9|       100.0|           0.0|           5.4|
# |Medchal-Malkajgiri| Uppal|16-01-2018|     0.0|    13.9|    35.5|        24.0|       100.0|           0.0|           4.0|
# |Medchal-Malkajgiri| Uppal|17-01-2018|     0.0|    12.0|    35.3|        18.0|       100.0|           0.0|           8.5|
# |Medchal-Malkajgiri| Uppal|18-01-2018|     0.0|    11.2|    33.7|        24.7|       100.0|           0.0|           6.1|
# |Medchal-Malkajgiri| Uppal|19-01-2018|     0.0|     9.6|    34.1|        21.6|       100.0|           0.0|           5.5|
# |Medchal-Malkajgiri| Uppal|20-01-2018|     0.0|     7.1|    34.0|        14.4|       100.0|           0.0|           5.5|
# +------------------+------+----------+--------+--------+--------+------------+------------+--------------+--------------+
# only showing top 20 rows
#
# After modifying the dataframe:
# +------------------+------+----------+--------+--------+--------+------------+------------+--------------+--------------+----+-----+---+
# |          district|mandal|      date|rainfall|temp_min|temp_max|humidity_min|humidity_max|wind_speed_min|wind_speed_max|year|month|day|
# +------------------+------+----------+--------+--------+--------+------------+------------+--------------+--------------+----+-----+---+
# |Medchal-Malkajgiri| Uppal|01-01-2018|     0.0|    12.1|    32.6|        23.8|       100.0|           0.0|           6.6|2018|   01| 01|
# |Medchal-Malkajgiri| Uppal|02-01-2018|     0.0|    11.6|    32.6|        23.2|       100.0|           0.0|           4.7|2018|   01| 02|
# |Medchal-Malkajgiri| Uppal|03-01-2018|     0.0|    13.0|    33.0|        31.5|       100.0|           0.0|           6.3|2018|   01| 03|
# |Medchal-Malkajgiri| Uppal|04-01-2018|     0.0|     9.7|    31.7|        27.4|       100.0|           0.0|           5.2|2018|   01| 04|
# |Medchal-Malkajgiri| Uppal|05-01-2018|     0.0|     8.8|    31.0|        28.6|       100.0|           0.0|           7.1|2018|   01| 05|
# |Medchal-Malkajgiri| Uppal|06-01-2018|     0.0|     8.7|    31.8|        22.0|       100.0|           0.0|           4.5|2018|   01| 06|
# |Medchal-Malkajgiri| Uppal|07-01-2018|     0.0|     9.2|    31.6|        21.4|       100.0|           0.0|           3.7|2018|   01| 07|
# |Medchal-Malkajgiri| Uppal|08-01-2018|     0.0|     9.6|   31.59|        23.8|       100.0|           0.0|           7.1|2018|   01| 08|
# |Medchal-Malkajgiri| Uppal|09-01-2018|     0.0|    10.5|    30.4|        26.5|       100.0|           0.0|           6.1|2018|   01| 09|
# |Medchal-Malkajgiri| Uppal|10-01-2018|     0.0|    10.8|    30.0|        35.7|       100.0|           0.0|           6.4|2018|   01| 10|
# |Medchal-Malkajgiri| Uppal|11-01-2018|     0.0|    11.8|    32.4|        34.0|       100.0|           0.0|           6.2|2018|   01| 11|
# |Medchal-Malkajgiri| Uppal|12-01-2018|     0.0|    11.8|    34.5|        30.7|       100.0|           0.0|           6.8|2018|   01| 12|
# |Medchal-Malkajgiri| Uppal|13-01-2018|     0.0|    11.7|    34.6|        21.1|       100.0|           0.0|           7.6|2018|   01| 13|
# |Medchal-Malkajgiri| Uppal|14-01-2018|     0.0|    11.4|    34.9|        18.6|        92.8|           0.0|           4.5|2018|   01| 14|
# |Medchal-Malkajgiri| Uppal|15-01-2018|     0.0|    14.3|    34.4|        25.9|       100.0|           0.0|           5.4|2018|   01| 15|
# |Medchal-Malkajgiri| Uppal|16-01-2018|     0.0|    13.9|    35.5|        24.0|       100.0|           0.0|           4.0|2018|   01| 16|
# |Medchal-Malkajgiri| Uppal|17-01-2018|     0.0|    12.0|    35.3|        18.0|       100.0|           0.0|           8.5|2018|   01| 17|
# |Medchal-Malkajgiri| Uppal|18-01-2018|     0.0|    11.2|    33.7|        24.7|       100.0|           0.0|           6.1|2018|   01| 18|
# |Medchal-Malkajgiri| Uppal|19-01-2018|     0.0|     9.6|    34.1|        21.6|       100.0|           0.0|           5.5|2018|   01| 19|
# |Medchal-Malkajgiri| Uppal|20-01-2018|     0.0|     7.1|    34.0|        14.4|       100.0|           0.0|           5.5|2018|   01| 20|
# +------------------+------+----------+--------+--------+--------+------------+------------+--------------+--------------+----+-----+---+
# only showing top 20 rows
#
# Districts with data count:
# +------------------+---------+
# |          district|row_count|
# +------------------+---------+
# |          Nalgonda|    61943|
# |        Rangareddy|    56289|
# |         Nizamabad|    51031|
# |        Sangareddy|    45751|
# |          Siddipet|    43154|
# |           Khammam|    42105|
# |          Suryapet|    41429|
# |             Medak|    39311|
# |      Nagarkurnool|    38414|
# |         Kamareddy|    38306|
# |      Mahabubnagar|    37488|
# |         Vikarabad|    34423|
# |           Jagtial|    34114|
# |            Nirmal|    33959|
# |        Mancherial|    31366|
# |        Karimnagar|    30116|
# |          Adilabad|    29462|
# |Medchal-Malkajgiri|    28523|
# |         Hyderabad|    28467|
# |       Mahabubabad|    28048|
# +------------------+---------+
# only showing top 20 rows
#
# Mandals with data count:
# +-------------+---------+
# |       mandal|row_count|
# +-------------+---------+
# |        Mulug|     4352|
# |Ibrahimpatnam|     4350|
# |       Dharur|     4174|
# |    Balanagar|     3807|
# |     Nawabpet|     3656|
# |      Chandur|     3138|
# |       Maddur|     3138|
# |   Sarangapur|     3138|
# |       Tandur|     3138|
# |      Atmakur|     3136|
# |      Gundala|     3136|
# |        Armur|     3123|
# |      Thoguta|     3123|
# |     Nalgonda|     3121|
# |       Bodhan|     3119|
# |       Madnur|     3119|
# |     Khanapur|     2702|
# |         Aiza|     2605|
# |        Alair|     2605|
# |   Chandampet|     2605|
# +-------------+---------+
# only showing top 20 rows
#
# Rank district by how long they have been online:
# +------------------------+--------+--------+--------+----------------+
# |district                |online_y|online_m|online_d|online_time_rank|
# +------------------------+--------+--------+--------+----------------+
# |Adilabad                |2018    |01      |01      |1               |
# |Bhadradri-Kothagudem    |2018    |01      |01      |1               |
# |Hyderabad               |2018    |01      |01      |1               |
# |Jagtial                 |2018    |01      |01      |1               |
# |Jangaon                 |2018    |01      |01      |1               |
# |Jayashankar-Bhupalpally |2018    |01      |01      |1               |
# |Jogulamba-Gadwal        |2018    |01      |01      |1               |
# |Kamareddy               |2018    |01      |01      |1               |
# |Karimnagar              |2018    |01      |01      |1               |
# |Khammam                 |2018    |01      |01      |1               |
# |Kumuram Bheem - Asifabad|2018    |01      |01      |1               |
# |Mahabubabad             |2018    |01      |01      |1               |
# |Mahabubnagar            |2018    |01      |01      |1               |
# |Mancherial              |2018    |01      |01      |1               |
# |Medak                   |2018    |01      |01      |1               |
# |Medchal-Malkajgiri      |2018    |01      |01      |1               |
# |Nagarkurnool            |2018    |01      |01      |1               |
# |Nalgonda                |2018    |01      |01      |1               |
# |Nirmal                  |2018    |01      |01      |1               |
# |Nizamabad               |2018    |01      |01      |1               |
# |Peddapalli              |2018    |01      |01      |1               |
# |Rajanna-Siricilla       |2018    |01      |01      |1               |
# |Rangareddy              |2018    |01      |01      |1               |
# |Sangareddy              |2018    |01      |01      |1               |
# |Siddipet                |2018    |01      |01      |1               |
# |Suryapet                |2018    |01      |01      |1               |
# |Vikarabad               |2018    |01      |01      |1               |
# |Wanaparthy              |2018    |01      |01      |1               |
# |Warangal (R)            |2018    |01      |01      |1               |
# |Warangal (U)            |2018    |01      |01      |1               |
# |Yadadri-Bhongir         |2018    |01      |01      |1               |
# |Narayanpet              |2019    |01      |01      |2               |
# |Warangal Rural          |2019    |01      |01      |2               |
# |Warangal Urban          |2019    |01      |01      |2               |
# |Mulug                   |2019    |06      |01      |3               |
# |Komaram Bheem-Asifabad  |2019    |09      |01      |4               |
# |Kumuram Bheem           |2020    |01      |01      |5               |
# |Mulugu                  |2020    |01      |01      |5               |
# |Bhadradri Kothagudem    |21      |Apr     |01      |6               |
# |Hanumakkonda            |21      |Apr     |01      |6               |
# |Jayashankar             |21      |Apr     |01      |6               |
# |Jogulamba Gadwal        |21      |Apr     |01      |6               |
# |Rajanna Sircilla        |21      |Apr     |01      |6               |
# |Warangal                |21      |Apr     |01      |6               |
# |Yadadri Bhuvanagiri     |21      |Apr     |01      |6               |
# |Hanumakonda             |22      |Aug     |01      |7               |
# +------------------------+--------+--------+--------+----------------+
#
# Rank mandal by how long they have been online:
# +----------------------+--------+--------+--------+----------------+
# |mandal                |online_y|online_m|online_d|online_time_rank|
# +----------------------+--------+--------+--------+----------------+
# |Abdullapurmet         |2018    |01      |01      |1               |
# |Achampet              |2018    |01      |01      |1               |
# |Adavidevulapalli      |2018    |01      |01      |1               |
# |Addagudur             |2018    |01      |01      |1               |
# |Addakal               |2018    |01      |01      |1               |
# |Adilabad (Urban)      |2018    |01      |01      |1               |
# |Adilabad Rural        |2018    |01      |01      |1               |
# |Aiza                  |2018    |01      |01      |1               |
# |Aiza                  |2018    |01      |01      |1               |
# |Akkannapeta           |2018    |01      |01      |1               |
# |Alair                 |2018    |01      |01      |1               |
# |Alampur               |2018    |01      |01      |1               |
# |Alladurg              |2018    |01      |01      |1               |
# |Allapalli             |2018    |01      |01      |1               |
# |Alwal                 |2018    |01      |01      |1               |
# |Amangal               |2018    |01      |01      |1               |
# |Amarchintha           |2018    |01      |01      |1               |
# |Amberpet              |2018    |01      |01      |1               |
# |Ameenapur             |2018    |01      |01      |1               |
# |Ameerpet              |2018    |01      |01      |1               |
# |Amrabad               |2018    |01      |01      |1               |
# |Ananthagiri           |2018    |01      |01      |1               |
# |Andhole               |2018    |01      |01      |1               |
# |Annapureddypalle      |2018    |01      |01      |1               |
# |Antargoan             |2018    |01      |01      |1               |
# |Anumula Haliya        |2018    |01      |01      |1               |
# |Armur                 |2018    |01      |01      |1               |
# |Armur                 |2018    |01      |01      |1               |
# |Asifabad              |2018    |01      |01      |1               |
# |Asifnagar             |2018    |01      |01      |1               |
# |Aswapuram             |2018    |01      |01      |1               |
# |Aswaraopeta           |2018    |01      |01      |1               |
# |Athmakur (M)          |2018    |01      |01      |1               |
# |Atmakur               |2018    |01      |01      |1               |
# |Atmakur_S             |2018    |01      |01      |1               |
# |Bachannapeta          |2018    |01      |01      |1               |
# |Bachpalle             |2018    |01      |01      |1               |
# |Bahadurpura           |2018    |01      |01      |1               |
# |Balanagar             |2018    |01      |01      |1               |
# |Balapur               |2018    |01      |01      |1               |
# |Balkonda              |2018    |01      |01      |1               |
# |Balmoor               |2018    |01      |01      |1               |
# |Bandlaguda            |2018    |01      |01      |1               |
# |Banswada              |2018    |01      |01      |1               |
# |Bantwaram             |2018    |01      |01      |1               |
# |Basar                 |2018    |01      |01      |1               |
# |Basheerabad           |2018    |01      |01      |1               |
# |Bayyaram              |2018    |01      |01      |1               |
# |Bazarhathnoor         |2018    |01      |01      |1               |
# |Beerpur               |2018    |01      |01      |1               |
# |Bejjanki              |2018    |01      |01      |1               |
# |Bejjur                |2018    |01      |01      |1               |
# |Bela                  |2018    |01      |01      |1               |
# |Bela                  |2018    |01      |01      |1               |
# |Bellampally           |2018    |01      |01      |1               |
# |Bhadrachalam          |2018    |01      |01      |1               |
# |Bhainsa               |2018    |01      |01      |1               |
# |Bhainsa               |2018    |01      |01      |1               |
# |Bheemadevarapalle     |2018    |01      |01      |1               |
# |Bheemaram             |2018    |01      |01      |1               |
# |Bheemgal              |2018    |01      |01      |1               |
# |Bheemini              |2018    |01      |01      |1               |
# |Bheempoor             |2018    |01      |01      |1               |
# |Bhiknoor              |2018    |01      |01      |1               |
# |Bhiknur               |2018    |01      |01      |1               |
# |Bhongir               |2018    |01      |01      |1               |
# |Bhoothpur             |2018    |01      |01      |1               |
# |Bhupalpalle           |2018    |01      |01      |1               |
# |Bibinagar             |2018    |01      |01      |1               |
# |Bibipet               |2018    |01      |01      |1               |
# |Bichkunda             |2018    |01      |01      |1               |
# |Bichkunda             |2018    |01      |01      |1               |
# |Bijinapalle           |2018    |01      |01      |1               |
# |Birkoor               |2018    |01      |01      |1               |
# |Boath                 |2018    |01      |01      |1               |
# |Boath                 |2018    |01      |01      |1               |
# |Bodhan                |2018    |01      |01      |1               |
# |Boinpalle             |2018    |01      |01      |1               |
# |Bommalaramaram        |2018    |01      |01      |1               |
# |Bomraspeta            |2018    |01      |01      |1               |
# |Bonakal               |2018    |01      |01      |1               |
# |Buggaram              |2018    |01      |01      |1               |
# |Burgampadu            |2018    |01      |01      |1               |
# |Chandampet            |2018    |01      |01      |1               |
# |Chandrugonda          |2018    |01      |01      |1               |
# |Chandur               |2018    |01      |01      |1               |
# |Chandurthi            |2018    |01      |01      |1               |
# |Charakonda            |2018    |01      |01      |1               |
# |Charminar             |2018    |01      |01      |1               |
# |Chegunta              |2018    |01      |01      |1               |
# |Chennaraopeta         |2018    |01      |01      |1               |
# |Chennur               |2018    |01      |01      |1               |
# |Chennur               |2018    |01      |01      |1               |
# |Cheriyal              |2018    |01      |01      |1               |
# |Cherla                |2018    |01      |01      |1               |
# |Chevella              |2018    |01      |01      |1               |
# |Chigurumamidi         |2018    |01      |01      |1               |
# |Chilkur               |2018    |01      |01      |1               |
# |Chilpched             |2018    |01      |01      |1               |
# |Chilpur               |2018    |01      |01      |1               |
# |Chinna Chintha Kunta  |2018    |01      |01      |1               |
# |Chinna_chintha_kunta  |2018    |01      |01      |1               |
# |Chinnagudur           |2018    |01      |01      |1               |
# |Chinnakodur           |2018    |01      |01      |1               |
# |Chinnambavi           |2018    |01      |01      |1               |
# |Chinnambavi           |2018    |01      |01      |1               |
# |Chintalamanepally     |2018    |01      |01      |1               |
# |Chinthakani           |2018    |01      |01      |1               |
# |Chinthalapalem        |2018    |01      |01      |1               |
# |Chinthapalle          |2018    |01      |01      |1               |
# |Chityal               |2018    |01      |01      |1               |
# |Chityala              |2018    |01      |01      |1               |
# |Chivvemla             |2018    |01      |01      |1               |
# |Choppadandi           |2018    |01      |01      |1               |
# |Choudergudem          |2018    |01      |01      |1               |
# |Choutuppal            |2018    |01      |01      |1               |
# |Chunchupally          |2018    |01      |01      |1               |
# |Dahegaon              |2018    |01      |01      |1               |
# |Damaracherla          |2018    |01      |01      |1               |
# |Damaragidda           |2018    |01      |01      |1               |
# |Damera                |2018    |01      |01      |1               |
# |Dammapeta             |2018    |01      |01      |1               |
# |Dammapeta             |2018    |01      |01      |1               |
# |Dandepalle            |2018    |01      |01      |1               |
# |Danthalapalle         |2018    |01      |01      |1               |
# |Dastuarabad           |2018    |01      |01      |1               |
# |Devarakadara          |2018    |01      |01      |1               |
# |Devarakonda           |2018    |01      |01      |1               |
# |Devaruppala           |2018    |01      |01      |1               |
# |Dhanwada              |2018    |01      |01      |1               |
# |Dharmapuri            |2018    |01      |01      |1               |
# |Dharmaram             |2018    |01      |01      |1               |
# |Dharmasagar           |2018    |01      |01      |1               |
# |Dharpalle             |2018    |01      |01      |1               |
# |Dharur                |2018    |01      |01      |1               |
# |Dichpalle             |2018    |01      |01      |1               |
# |Dilawarpur            |2018    |01      |01      |1               |
# |Doma                  |2018    |01      |01      |1               |
# |Domakonda             |2018    |01      |01      |1               |
# |Dornakal              |2018    |01      |01      |1               |
# |Doultabad             |2018    |01      |01      |1               |
# |Doulthabad            |2018    |01      |01      |1               |
# |Dubbak                |2018    |01      |01      |1               |
# |Duggondi              |2018    |01      |01      |1               |
# |Dummugudem            |2018    |01      |01      |1               |
# |Dundigal Gandimaisamma|2018    |01      |01      |1               |
# |Elgaid                |2018    |01      |01      |1               |
# |Elkathurthi           |2018    |01      |01      |1               |
# |Ellandakunta          |2018    |01      |01      |1               |
# |Ellanthakunta         |2018    |01      |01      |1               |
# |Enkuru                |2018    |01      |01      |1               |
# |Eturunagaram          |2018    |01      |01      |1               |
# |Farooqnagar           |2018    |01      |01      |1               |
# |Gadiguda              |2018    |01      |01      |1               |
# |Gadwal                |2018    |01      |01      |1               |
# |Gajwel                |2018    |01      |01      |1               |
# |Gambhiraopeta         |2018    |01      |01      |1               |
# |Gandeed               |2018    |01      |01      |1               |
# |Gandhari              |2018    |01      |01      |1               |
# |Gandipet              |2018    |01      |01      |1               |
# |Gangadhara            |2018    |01      |01      |1               |
# |Gangavaram            |2018    |01      |01      |1               |
# |Gannervaram           |2018    |01      |01      |1               |
# |Garidepalle           |2018    |01      |01      |1               |
# |Garla                 |2018    |01      |01      |1               |
# |Geesugonda            |2018    |01      |01      |1               |
# |Ghanpur               |2018    |01      |01      |1               |
# |Ghanpur (Mulug)       |2018    |01      |01      |1               |
# |Ghanpur (Stn)         |2018    |01      |01      |1               |
# |Ghatkesar             |2018    |01      |01      |1               |
# |Ghatkeshar            |2018    |01      |01      |1               |
# |Ghattu                |2018    |01      |01      |1               |
# |Golkonda              |2018    |01      |01      |1               |
# |Gollapalle            |2018    |01      |01      |1               |
# |Gopalpeta             |2018    |01      |01      |1               |
# |Govindaraopet         |2018    |01      |01      |1               |
# |Gudihatnoor           |2018    |01      |01      |1               |
# |Gudur                 |2018    |01      |01      |1               |
# |Gummadidala           |2018    |01      |01      |1               |
# |Gummadidala           |2018    |01      |01      |1               |
# |Gundala               |2018    |01      |01      |1               |
# |Gundlapalle           |2018    |01      |01      |1               |
# |Gurrampode            |2018    |01      |01      |1               |
# |Hajipur               |2018    |01      |01      |1               |
# |Hanamkonda            |2018    |01      |01      |1               |
# |Hanwada               |2018    |01      |01      |1               |
# |Hasanparthy           |2018    |01      |01      |1               |
# |Hathanoora            |2018    |01      |01      |1               |
# |Havelighanpur         |2018    |01      |01      |1               |
# |Hayathnagar           |2018    |01      |01      |1               |
# |Himayatnagar          |2018    |01      |01      |1               |
# |Husnabad              |2018    |01      |01      |1               |
# |Huzurabad             |2018    |01      |01      |1               |
# |Huzurnagar            |2018    |01      |01      |1               |
# |Ibrahimpatnam         |2018    |01      |01      |1               |
# |Ichoda                |2018    |01      |01      |1               |
# |Indalwai              |2018    |01      |01      |1               |
# |Inderavelly           |2018    |01      |01      |1               |
# |Inole                 |2018    |01      |01      |1               |
# |Itikyal               |2018    |01      |01      |1               |
# |Jadcherla             |2018    |01      |01      |1               |
# |Jagadevpur            |2018    |01      |01      |1               |
# |Jagitial Rural        |2018    |01      |01      |1               |
# |Jagtial               |2018    |01      |01      |1               |
# |Jainad                |2018    |01      |01      |1               |
# |Jainad                |2018    |01      |01      |1               |
# |Jainath               |2018    |01      |01      |1               |
# |Jainoor               |2018    |01      |01      |1               |
# |Jaipur                |2018    |01      |01      |1               |
# |Jaipur                |2018    |01      |01      |1               |
# |Jajireddigudem        |2018    |01      |01      |1               |
# |Jakranpalle           |2018    |01      |01      |1               |
# |Jammikunta            |2018    |01      |01      |1               |
# |Jammikunta            |2018    |01      |01      |1               |
# |Jangaon               |2018    |01      |01      |1               |
# |Jannaram              |2018    |01      |01      |1               |
# |Jharasangam           |2018    |01      |01      |1               |
# |Jinnaram              |2018    |01      |01      |1               |
# |Jukkal                |2018    |01      |01      |1               |
# |Julapalle             |2018    |01      |01      |1               |
# |Julurpad              |2018    |01      |01      |1               |
# |Kaddam Peddur         |2018    |01      |01      |1               |
# |Kaddampeddur          |2018    |01      |01      |1               |
# |Kadthal               |2018    |01      |01      |1               |
# |Kagaznagar            |2018    |01      |01      |1               |
# |Kagaznagar            |2018    |01      |01      |1               |
# |Kalher                |2018    |01      |01      |1               |
# |Kalluru               |2018    |01      |01      |1               |
# |Kaloor Timmanadoddi   |2018    |01      |01      |1               |
# |Kaloor_Timmanadoddi   |2018    |01      |01      |1               |
# |Kalwakurthy           |2018    |01      |01      |1               |
# |Kamalapur             |2018    |01      |01      |1               |
# |Kamanpur              |2018    |01      |01      |1               |
# |Kamareddy             |2018    |01      |01      |1               |
# |Kamepalle             |2018    |01      |01      |1               |
# |Kammarpalle           |2018    |01      |01      |1               |
# |Kammarpalle           |2018    |01      |01      |1               |
# |Kanagal               |2018    |01      |01      |1               |
# |Kandi                 |2018    |01      |01      |1               |
# |Kandukur              |2018    |01      |01      |1               |
# |Kangti                |2018    |01      |01      |1               |
# |Kannaigudem           |2018    |01      |01      |1               |
# |Kannepalli            |2018    |01      |01      |1               |
# |Kapra                 |2018    |01      |01      |1               |
# |Karakagudem           |2018    |01      |01      |1               |
# |Karimnagar            |2018    |01      |01      |1               |
# |Karimnagar Rural      |2018    |01      |01      |1               |
# |Karimnagar_Rural      |2018    |01      |01      |1               |
# |Kasipet               |2018    |01      |01      |1               |
# |Kataram               |2018    |01      |01      |1               |
# |Kathlapur             |2018    |01      |01      |1               |
# |Kattangoor            |2018    |01      |01      |1               |
# |Keesara               |2018    |01      |01      |1               |
# |Kerameri              |2018    |01      |01      |1               |
# |Kesamudram            |2018    |01      |01      |1               |
# |Kesamudram            |2018    |01      |01      |1               |
# |Keshampet             |2018    |01      |01      |1               |
# |Kethepalle            |2018    |01      |01      |1               |
# |Khairatabad           |2018    |01      |01      |1               |
# |Khammam (Rural)       |2018    |01      |01      |1               |
# |Khammam (Urban)       |2018    |01      |01      |1               |
# |Khammam_Urban         |2018    |01      |01      |1               |
# |Khanapur              |2018    |01      |01      |1               |
# |Khazipet              |2018    |01      |01      |1               |
# |Khilla Warangal       |2018    |01      |01      |1               |
# |Kodad                 |2018    |01      |01      |1               |
# |Kodair                |2018    |01      |01      |1               |
# |Kodakandla            |2018    |01      |01      |1               |
# |Kodangal              |2018    |01      |01      |1               |
# |Kodimial              |2018    |01      |01      |1               |
# |Koheda                |2018    |01      |01      |1               |
# |Kohir                 |2018    |01      |01      |1               |
# |Koilkonda             |2018    |01      |01      |1               |
# |Kollapur              |2018    |01      |01      |1               |
# |Komuravelli           |2018    |01      |01      |1               |
# |Konaraopeta           |2018    |01      |01      |1               |
# |Kondamallapally       |2018    |01      |01      |1               |
# |Kondapak              |2018    |01      |01      |1               |
# |Kondapak              |2018    |01      |01      |1               |
# |Kondapur              |2018    |01      |01      |1               |
# |Kondurg               |2018    |01      |01      |1               |
# |Konijerla             |2018    |01      |01      |1               |
# |Koratla               |2018    |01      |01      |1               |
# |Kosgi                 |2018    |01      |01      |1               |
# |Kotapalle             |2018    |01      |01      |1               |
# |Kotapally             |2018    |01      |01      |1               |
# |Kotepally             |2018    |01      |01      |1               |
# |Kotgiri               |2018    |01      |01      |1               |
# |Kothaguda             |2018    |01      |01      |1               |
# |Kothagudem            |2018    |01      |01      |1               |
# |Kothakota             |2018    |01      |01      |1               |
# |Kothapalle            |2018    |01      |01      |1               |
# |Kothur                |2018    |01      |01      |1               |
# |Kouthala              |2018    |01      |01      |1               |
# |Kowdipalle            |2018    |01      |01      |1               |
# |Krishna               |2018    |01      |01      |1               |
# |Kubeer                |2018    |01      |01      |1               |
# |Kukatpally            |2018    |01      |01      |1               |
# |Kulcharam             |2018    |01      |01      |1               |
# |Kulkacherla           |2018    |01      |01      |1               |
# |Kuntala               |2018    |01      |01      |1               |
# |Kuravi                |2018    |01      |01      |1               |
# |Kusumanchi            |2018    |01      |01      |1               |
# |Laxmanchanda          |2018    |01      |01      |1               |
# |Laxmanchanda          |2018    |01      |01      |1               |
# |Laxmidevipalli        |2018    |01      |01      |1               |
# |Lingal                |2018    |01      |01      |1               |
# |Lingalaghanpur        |2018    |01      |01      |1               |
# |Lingampet             |2018    |01      |01      |1               |
# |Lingapur              |2018    |01      |01      |1               |
# |Lokeswaram            |2018    |01      |01      |1               |
# |Luxettipet            |2018    |01      |01      |1               |
# |Machareddy            |2018    |01      |01      |1               |
# |Madanapur             |2018    |01      |01      |1               |
# |Maddirala             |2018    |01      |01      |1               |
# |Maddur                |2018    |01      |01      |1               |
# |Madgul                |2018    |01      |01      |1               |
# |Madhira               |2018    |01      |01      |1               |
# |Madnur                |2018    |01      |01      |1               |
# |Madugulapally         |2018    |01      |01      |1               |
# |Maganoor              |2018    |01      |01      |1               |
# |Mahabubabad           |2018    |01      |01      |1               |
# |Mahabubnagar (U)      |2018    |01      |01      |1               |
# |Mahabubnagar Rural    |2018    |01      |01      |1               |
# |Mahadevpur            |2018    |01      |01      |1               |
# |Mahadevpur            |2018    |01      |01      |1               |
# |Maheshwaram           |2018    |01      |01      |1               |
# |Makloor               |2018    |01      |01      |1               |
# |Makthal               |2018    |01      |01      |1               |
# |Maldakal              |2018    |01      |01      |1               |
# |Malhalrrao            |2018    |01      |01      |1               |
# |Malharrao             |2018    |01      |01      |1               |
# |Malial                |2018    |01      |01      |1               |
# |Malkajgiri            |2018    |01      |01      |1               |
# |Mallapur              |2018    |01      |01      |1               |
# |Mamda                 |2018    |01      |01      |1               |
# |Manakondur            |2018    |01      |01      |1               |
# |Manakondur            |2018    |01      |01      |1               |
# |Manchal               |2018    |01      |01      |1               |
# |Mancherial            |2018    |01      |01      |1               |
# |Mandamarri            |2018    |01      |01      |1               |
# |Mangapet              |2018    |01      |01      |1               |
# |Manoharabad           |2018    |01      |01      |1               |
# |Manoor                |2018    |01      |01      |1               |
# |Manopad               |2018    |01      |01      |1               |
# |Manthani              |2018    |01      |01      |1               |
# |Manuguru              |2018    |01      |01      |1               |
# |Marikal               |2018    |01      |01      |1               |
# |Maripeda              |2018    |01      |01      |1               |
# |Markook               |2018    |01      |01      |1               |
# |Marpalle              |2018    |01      |01      |1               |
# |Marredpally           |2018    |01      |01      |1               |
# |Marriguda             |2018    |01      |01      |1               |
# |Mattampalle           |2018    |01      |01      |1               |
# |Mattampalle           |2018    |01      |01      |1               |
# |Mavala                |2018    |01      |01      |1               |
# |Medak                 |2018    |01      |01      |1               |
# |Medchal               |2018    |01      |01      |1               |
# |Medchel               |2018    |01      |01      |1               |
# |Medipalle             |2018    |01      |01      |1               |
# |Medipally             |2018    |01      |01      |1               |
# |Mellachervu           |2018    |01      |01      |1               |
# |Mendora               |2018    |01      |01      |1               |
# |Metpalle              |2018    |01      |01      |1               |
# |Midjil                |2018    |01      |01      |1               |
# |Mirdoddi              |2018    |01      |01      |1               |
# |Miryalaguda           |2018    |01      |01      |1               |
# |Mogdampalle           |2018    |01      |01      |1               |
# |Mogullapalle          |2018    |01      |01      |1               |
# |Moinabad              |2018    |01      |01      |1               |
# |Moinabad              |2018    |01      |01      |1               |
# |Mominpet              |2018    |01      |01      |1               |
# |Mootakondur           |2018    |01      |01      |1               |
# |Mortad                |2018    |01      |01      |1               |
# |Mothey                |2018    |01      |01      |1               |
# |Mothkur               |2018    |01      |01      |1               |
# |Mudhole               |2018    |01      |01      |1               |
# |Mudigonda             |2018    |01      |01      |1               |
# |Mugpal                |2018    |01      |01      |1               |
# |Mulakalapalle         |2018    |01      |01      |1               |
# |Mulug                 |2018    |01      |01      |1               |
# |Munagala              |2018    |01      |01      |1               |
# |Munipalli             |2018    |01      |01      |1               |
# |Munugode              |2018    |01      |01      |1               |
# |Mupkal                |2018    |01      |01      |1               |
# |Musapet               |2018    |01      |01      |1               |
# |Musheerabad           |2018    |01      |01      |1               |
# |Mustabad              |2018    |01      |01      |1               |
# |Mutharam Mahadevpur   |2018    |01      |01      |1               |
# |Mutharam Manthani     |2018    |01      |01      |1               |
# |Mutharam_Mahadevpur   |2018    |01      |01      |1               |
# |Nadigudem             |2018    |01      |01      |1               |
# |Nagalgidda            |2018    |01      |01      |1               |
# |Nagaram               |2018    |01      |01      |1               |
# |Nagarkurnool          |2018    |01      |01      |1               |
# |Nagireddypet          |2018    |01      |01      |1               |
# |Nakrekal              |2018    |01      |01      |1               |
# |Nalgonda              |2018    |01      |01      |1               |
# |Nallabelly            |2018    |01      |01      |1               |
# |Nampalle              |2018    |01      |01      |1               |
# |Nampally              |2018    |01      |01      |1               |
# |Nandigama             |2018    |01      |01      |1               |
# |Nandipet              |2018    |01      |01      |1               |
# |Nanganur              |2018    |01      |01      |1               |
# |Narayanapur           |2018    |01      |01      |1               |
# |Narayankhed           |2018    |01      |01      |1               |
# |Narayanpet            |2018    |01      |01      |1               |
# |Narketpalle           |2018    |01      |01      |1               |
# |Narmetta              |2018    |01      |01      |1               |
# |Narnoor               |2018    |01      |01      |1               |
# |Narsampet             |2018    |01      |01      |1               |
# |Narsapur              |2018    |01      |01      |1               |
# |Narsapur G            |2018    |01      |01      |1               |
# |Narsimhulapet         |2018    |01      |01      |1               |
# |Narsingi              |2018    |01      |01      |1               |
# |Narva                 |2018    |01      |01      |1               |
# |Naspur                |2018    |01      |01      |1               |
# |Nasurullabad          |2018    |01      |01      |1               |
# |Navipet               |2018    |01      |01      |1               |
# |Nawabpet              |2018    |01      |01      |1               |
# |Nekkonda              |2018    |01      |01      |1               |
# |Nelakondapalle        |2018    |01      |01      |1               |
# |Nellikudur            |2018    |01      |01      |1               |
# |Nellikudur            |2018    |01      |01      |1               |
# |Nennal                |2018    |01      |01      |1               |
# |Neradigonda           |2018    |01      |01      |1               |
# |Neredcherla           |2018    |01      |01      |1               |
# |Neredugommu           |2018    |01      |01      |1               |
# |Nidamanur             |2018    |01      |01      |1               |
# |Nirmal                |2018    |01      |01      |1               |
# |Nirmal Rural          |2018    |01      |01      |1               |
# |Nizamabad North       |2018    |01      |01      |1               |
# |Nizamabad Rural       |2018    |01      |01      |1               |
# |Nizamabad South       |2018    |01      |01      |1               |
# |Nizampet              |2018    |01      |01      |1               |
# |Nizamsagar            |2018    |01      |01      |1               |
# |Noothankal            |2018    |01      |01      |1               |
# |Nyalkal               |2018    |01      |01      |1               |
# |Odela                 |2018    |01      |01      |1               |
# |Padra                 |2018    |01      |01      |1               |
# |Palakeedu             |2018    |01      |01      |1               |
# |Palakurthi            |2018    |01      |01      |1               |
# |Palakurthy            |2018    |01      |01      |1               |
# |Palimela              |2018    |01      |01      |1               |
# |Palwancha             |2018    |01      |01      |1               |
# |Pangal                |2018    |01      |01      |1               |
# |Pangal                |2018    |01      |01      |1               |
# |Papannapet            |2018    |01      |01      |1               |
# |Papannapet            |2018    |01      |01      |1               |
# |Pargi                 |2018    |01      |01      |1               |
# |Parkal                |2018    |01      |01      |1               |
# |Parvathagiri          |2018    |01      |01      |1               |
# |Patancheruvu          |2018    |01      |01      |1               |
# |Pebbair               |2018    |01      |01      |1               |
# |Pedda Adesherlapalle  |2018    |01      |01      |1               |
# |Pedda Kodapgal        |2018    |01      |01      |1               |
# |Peddakothapalle       |2018    |01      |01      |1               |
# |Peddamandadi          |2018    |01      |01      |1               |
# |Peddapalle            |2018    |01      |01      |1               |
# |Peddapalli            |2018    |01      |01      |1               |
# |Peddavangara          |2018    |01      |01      |1               |
# |Peddavura             |2018    |01      |01      |1               |
# |Peddemul              |2018    |01      |01      |1               |
# |Pegadapalle           |2018    |01      |01      |1               |
# |Pembi                 |2018    |01      |01      |1               |
# |Penchikalpet          |2018    |01      |01      |1               |
# |Penpahad              |2018    |01      |01      |1               |
# |Pentlavelli           |2018    |01      |01      |1               |
# |Penuballi             |2018    |01      |01      |1               |
# |Pinapaka              |2018    |01      |01      |1               |
# |Pitlam                |2018    |01      |01      |1               |
# |Pochampalle           |2018    |01      |01      |1               |
# |Pudur                 |2018    |01      |01      |1               |
# |Pulkal                |2018    |01      |01      |1               |
# |Pulkal                |2018    |01      |01      |1               |
# |Qutballapur           |2018    |01      |01      |1               |
# |Quthbullapur          |2018    |01      |01      |1               |
# |Raghunadhapalem       |2018    |01      |01      |1               |
# |Raghunadhapalem       |2018    |01      |01      |1               |
# |Raghunathpalle        |2018    |01      |01      |1               |
# |Raikal                |2018    |01      |01      |1               |
# |Raikode               |2018    |01      |01      |1               |
# |Raiparthy             |2018    |01      |01      |1               |
# |Rajampet              |2018    |01      |01      |1               |
# |Rajapet               |2018    |01      |01      |1               |
# |Rajapur               |2018    |01      |01      |1               |
# |Rajendranagar         |2018    |01      |01      |1               |
# |Rajendranagar         |2018    |01      |01      |1               |
# |Rajoli                |2018    |01      |01      |1               |
# |Ramadugu              |2018    |01      |01      |1               |
# |Ramagiri              |2018    |01      |01      |1               |
# |Ramagundam            |2018    |01      |01      |1               |
# |Ramagundam            |2018    |01      |01      |1               |
# |Ramannapeta           |2018    |01      |01      |1               |
# |Ramareddy             |2018    |01      |01      |1               |
# |Ramayampet            |2018    |01      |01      |1               |
# |Ramchandrapuram       |2018    |01      |01      |1               |
# |Ranjal                |2018    |01      |01      |1               |
# |Rayapole              |2018    |01      |01      |1               |
# |Rebbena               |2018    |01      |01      |1               |
# +----------------------+--------+--------+--------+----------------+
# only showing top 500 rows
#
# district rank by total rain fall:
# +------------------------+--------------+-------------+
# |district                |total_rainfall|rainfall_rank|
# +------------------------+--------------+-------------+
# |Nizamabad               |190355.8      |1            |
# |Kamareddy               |132025.1      |2            |
# |Siddipet                |129705.4      |3            |
# |Khammam                 |123810.1      |4            |
# |Jagtial                 |122779.7      |5            |
# |Rangareddy              |121621.3      |6            |
# |Nirmal                  |121236.9      |7            |
# |Mancherial              |116652.5      |8            |
# |Adilabad                |116624.9      |9            |
# |Nalgonda                |116474.8      |10           |
# |Sangareddy              |116202.8      |11           |
# |Medak                   |107216.9      |12           |
# |Karimnagar              |105462.9      |13           |
# |Suryapet                |96384.9       |14           |
# |Mahabubabad             |95477.4       |15           |
# |Peddapalli              |95229.3       |16           |
# |Bhadradri-Kothagudem    |93994.8       |17           |
# |Vikarabad               |85625.0       |18           |
# |Mahabubnagar            |77428.3       |19           |
# |Nagarkurnool            |72354.4       |20           |
# |Hyderabad               |68320.8       |21           |
# |Jangaon                 |68003.7       |22           |
# |Kumuram Bheem           |67944.4       |23           |
# |Jayashankar-Bhupalpally |67526.8       |24           |
# |Medchal-Malkajgiri      |67244.3       |25           |
# |Bhadradri Kothagudem    |65494.7       |26           |
# |Wanaparthy              |53111.4       |27           |
# ...
# |Annapureddipalle      |2020|1591.4        |
# |Tamsi                 |21  |1588.2        |
# |Vailpur               |21  |1583.2        |
# |Chennur               |22  |1583.2        |
# |Bayyaram              |21  |1582.7        |
# |Aswaraopeta           |21  |1581.3        |
# |Huzurabad             |21  |1578.7        |
# |Narsapur              |2018|1576.4        |
# |Yellandu              |2020|1568.8        |
# |Bhupalpalle           |22  |1568.3        |
# |Narsampet             |2020|1568.1        |
# |Kamalapur             |2018|1565.7        |
# |Pegadapalle           |22  |1563.1        |
# |Domakonda             |21  |1562.8        |
# |27                    |21  |1559.3        |
# |Qutballapur           |2018|1556.7        |
# |Jagityal_Rural        |22  |1556.6        |
# |Damera                |2020|1555.4        |
# |Penchikalpet          |22  |1555.3        |
# |Luxettipet            |22  |1550.5        |
# |Narsapur_G            |22  |1550.5        |
# |Maheshwaram           |2018|1550.4        |
# |Veernapalle           |21  |1549.2        |
# |Peddapalle            |22  |1547.1        |
# |Ghanpur (Mulug)       |2018|1541.9        |
# |Laxmidevipalli        |21  |1539.7        |
# |Boinpalle             |21  |1535.5        |
# |Gajwel                |2018|1533.9        |
# |V_Saidapur            |21  |1531.3        |
# |Chinthakani           |2018|1528.2        |
# |Nirmal_Rural          |22  |1527.3        |
# |Kondapak              |2020|1526.0        |
# |Gannervaram           |2020|1526.0        |
# |Damaragidda           |2018|1525.3        |
# |Bheemadevarapalle     |2020|1523.4        |
# |Kamepalle             |21  |1522.6        |
# |Garla                 |2020|1521.2        |
# |Ellandakunta          |21  |1517.7        |
# |Gudihatnoor           |2018|1515.5        |
# |Nizamabad_South       |21  |1514.4        |
# |Chandurthi            |22  |1512.9        |
# |Bibipet               |21  |1509.3        |
# |Tadwai                |22  |1508.5        |
# |Mugpal                |22  |1506.0        |
# |Nizamsagar            |2018|1505.4        |
# |Sujathanagar          |21  |1505.2        |
# |Parvathagiri          |2018|1501.9        |
# |Atmakur_S             |22  |1498.7        |
# |Kesamudram            |2020|1498.7        |
# |Nagarkurnool          |2018|1495.3        |
# |Varni                 |21  |1481.4        |
# |Palwancha             |2018|1480.2        |
# |Elkathurthi           |21  |1479.8        |
# |Serilingampally       |2018|1477.5        |
# |Tekulapalle           |2020|1468.5        |
# |Ganpur_Stn            |2020|1464.9        |
# |Gollapalle            |22  |1462.2        |
# |Yellareddypeta        |21  |1462.2        |
# |Mancherial            |22  |1460.2        |
# |Vemulawada_Rural      |2020|1457.6        |
# |Buggaram              |22  |1453.5        |
# |Naga_Reddipet         |22  |1452.8        |
# |Kodakandla            |22  |1452.6        |
# |Kangti                |21  |1452.2        |
# |Kotgiri               |21  |1451.9        |
# |Wanaparthy            |2020|1449.1        |
# |Shankarampet_R        |2020|1447.9        |
# |Banswada              |22  |1443.4        |
# |Gudihathnur           |22  |1441.9        |
# |Jakranpalle           |21  |1437.0        |
# |Ramareddy             |21  |1435.7        |
# |Talamadugu            |21  |1430.8        |
# |Vemsoor               |21  |1430.0        |
# |Konaraopeta           |2018|1428.5        |
# |Addakal               |2020|1426.6        |
# |Mandamarri            |22  |1419.5        |
# |Nagaram               |22  |1416.0        |
# |Karimnagar            |22  |1405.3        |
# |Raghunathpalle        |2020|1405.2        |
# |Komaravelly           |2020|1404.1        |
# |Kollapur              |2020|1403.4        |
# |Gambhiraopeta         |21  |1401.4        |
# |Nanganur              |21  |1400.2        |
# |Julurpad              |2020|1396.8        |
# |Mutharam_Manthani     |22  |1388.2        |
# |Singareni             |2020|1387.8        |
# |Yellareddy            |22  |1387.5        |
# |Pargi                 |2018|1387.5        |
# |Birkoor               |21  |1384.2        |
# |Kandukur              |2018|1381.5        |
# |Kothapalle            |22  |1378.4        |
# |Narmetta              |2020|1378.1        |
# |Velair                |2020|1378.1        |
# |Bhiknur               |21  |1375.6        |
# |Garidepalle           |2018|1368.9        |
# |Kagaznagar            |22  |1365.3        |
# |Bhimaram              |22  |1364.6        |
# |Indalwai              |22  |1363.5        |
# |Nasurullabad          |21  |1361.0        |
# |Nizamabad_North       |22  |1360.8        |
# |Naspur                |22  |1353.0        |
# |Sadasivanagar         |21  |1352.4        |
# |Bachannapeta          |21  |1351.7        |
# |Zaffergadh            |2018|1351.3        |
# |Bichkunda             |2020|1346.4        |
# |Gadwal                |2020|1345.3        |
# |Julapalle             |22  |1345.1        |
# |Akkannapeta           |2018|1343.3        |
# |Kulcharam             |21  |1341.7        |
# |Khammam_Urban         |21  |1336.8        |
# |Veenavanka            |21  |1336.1        |
# |Midjil                |2018|1336.1        |
# |Utkoor                |2020|1335.6        |
# |Bheemini              |22  |1325.1        |
# |Chinnakodur           |21  |1324.8        |
# |Patancheruvu          |2018|1323.4        |
# |Bhongiri              |21  |1322.5        |
# |Ghanpur               |2020|1322.4        |
# |Lingampet             |22  |1320.9        |
# |Thipparthi            |2018|1318.4        |
# |Soan                  |22  |1303.9        |
# |Pitlam                |21  |1301.4        |
# |Gopalpeta             |2020|1298.7        |
# |Jainad                |21  |1297.7        |
# |Manoor                |21  |1297.7        |
# |Gundlapalle           |2018|1297.5        |
# |Mogdampalle           |21  |1286.0        |
# |Anthakkapeta          |21  |1284.9        |
# |Bela                  |21  |1284.2        |
# |Nizampet              |2020|1284.0        |
# |24                    |21  |1283.3        |
# |Bijinapalle           |2018|1282.7        |
# |Ramagiri              |22  |1279.1        |
# |Devarkadara           |2020|1277.0        |
# |Chegunta              |2020|1274.0        |
# |Nellikudur            |22  |1274.0        |
# |Devaruppala           |22  |1271.9        |
# |Peddamandadi          |2020|1271.2        |
# |Mutharam Manthani     |2018|1271.2        |
# |Kohir                 |2018|1270.9        |
# |Khairatabad           |2018|1268.4        |
# |Maripeda              |22  |1265.3        |
# |Jinnaram              |22  |1264.2        |
# |Farooqnagar           |2018|1263.5        |
# |Mavala                |2018|1260.8        |
# |Doultabad             |2020|1260.1        |
# |Pedda Kodapgal        |21  |1259.8        |
# |Rudrur                |21  |1259.4        |
# |Yeldurthy             |2018|1258.3        |
# |Bantwaram             |21  |1257.8        |
# |Jagadevpur            |2020|1256.7        |
# |Rajapet               |21  |1253.8        |
# |Narayanraopet         |21  |1250.8        |
# |Danthalapalle         |22  |1250.3        |
# |Pudur                 |21  |1250.0        |
# |Yadagirigutta         |21  |1246.4        |
# |Mirdoddi              |21  |1246.3        |
# |Jangaon               |2018|1245.9        |
# |Thorrur               |2020|1244.6        |
# |Ramannapeta           |2018|1240.8        |
# |Ghanpur (Stn)         |2018|1240.2        |
# |Yacharam              |2018|1239.5        |
# |Chinnagudur           |21  |1239.3        |
# |Dharpalle             |21  |1239.1        |
# |Kalher                |2020|1238.7        |
# |Nadigudem             |21  |1238.2        |
# |Mahabubnagar_Rural    |2020|1236.1        |
# |Raiparthy             |2020|1235.4        |
# |Bachpalle             |22  |1234.3        |
# |Pangal                |2020|1233.9        |
# |Narayankhed           |21  |1230.7        |
# |Bomraspeta            |2018|1230.7        |
# |Mominpet              |21  |1229.3        |
# |Jainath               |2018|1229.0        |
# |Penpahad              |2018|1226.3        |
# |Bonakal               |21  |1226.0        |
# |Kotepally             |2020|1223.9        |
# |Narketpalle           |2018|1221.9        |
# |Palimela              |2019|1220.9        |
# |Thirumalagiri         |21  |1216.6        |
# |Tharigoppula          |2020|1214.3        |
# |Krishna               |2020|1213.7        |
# |Bhoothpur             |2020|1211.1        |
# |Narsingi              |22  |1208.6        |
# |Peddemul              |22  |1207.3        |
# |Tekmal                |2020|1203.2        |
# |Manoharabad           |2018|1201.0        |
# |Hanwada               |2020|1200.7        |
# |Nelakondapalle        |21  |1199.0        |
# |Tupran                |21  |1196.9        |
# |Andhole               |2020|1196.4        |
# |Alair                 |2018|1195.6        |
# |Chivvemla             |2018|1192.1        |
# |Saroornagar           |21  |1191.7        |
# |Abdullapurmet         |21  |1191.1        |
# |Khammam_Rural         |21  |1189.9        |
# |Bheempoor             |22  |1189.8        |
# |Lingalaghanpur        |21  |1189.6        |
# |Mahabubnagar_Urban    |2020|1189.2        |
# |Wargal                |21  |1187.9        |
# |Papannapet            |2020|1186.8        |
# |Doma                  |2020|1186.0        |
# |Gummadidala           |2020|1185.1        |
# |Gangavaram            |2018|1185.0        |
# |Kulkacharla           |21  |1184.2        |
# |Uppal                 |2018|1184.0        |
# |Kangal                |21  |1181.7        |
# |Saidabad              |21  |1179.9        |
# |Shamshabad            |2020|1178.5        |
# |Nagalgidda            |21  |1176.4        |
# |Narsimhulapet         |21  |1173.9        |
# |Hayathnagar           |21  |1171.3        |
# |Telkapalle            |2020|1169.4        |
# |Thirumalayapalem      |21  |1168.1        |
# |Shankarampet_A        |2020|1166.6        |
# |Madanapur             |2020|1164.8        |
# |Jajireddigudem        |22  |1159.4        |
# |Wardhannapet          |2020|1157.4        |
# |Pochampalle           |21  |1153.1        |
# |Chilpur               |22  |1152.5        |
# |Shivampet             |22  |1149.3        |
# |Balapur               |2018|1148.5        |
# |Odela                 |2020|1148.2        |
# |Chandrugonda          |21  |1146.3        |
# |Regode                |2020|1145.2        |
# |Kowdipalle            |21  |1145.0        |
# |Manchal               |21  |1144.2        |
# |Yerrupalem            |21  |1143.2        |
# |Siricilla             |2018|1140.2        |
# |Kalluru               |2020|1139.9        |
# |Lingal                |2020|1139.0        |
# |Cheriyal              |2018|1134.5        |
# |Peddavangara          |22  |1131.3        |
# |Markook               |21  |1128.5        |
# |Munugode              |21  |1128.2        |
# |Sirgapoor             |21  |1127.5        |
# |Noothankal            |22  |1125.4        |
# |Nandigam              |2020|1123.9        |
# |Ameenapur             |22  |1123.3        |
# |Kondurg               |2020|1119.9        |
# |Alladurg              |22  |1116.1        |
# |Veepangandla          |2020|1110.6        |
# |Keesara               |2020|1109.4        |
# |Ananthagiri           |2018|1106.7        |
# |Mothey                |21  |1106.1        |
# |Kosgi                 |2020|1105.1        |
# |Koilkonda             |2020|1103.4        |
# |Addagudur             |22  |1102.9        |
# |Dundigal_Gandimaisamma|22  |1102.2        |
# |Padra                 |2018|1102.1        |
# |Hanumakonda           |22  |1099.6        |
# |Dhanwada              |21  |1099.2        |
# |Maredpally            |21  |1099.0        |
# |Chowdergudem          |22  |1098.5        |
# |Naykal                |21  |1098.3        |
# |Chityala              |21  |1097.5        |
# |Rajendranagar         |2020|1096.1        |
# |Nakrekal              |22  |1093.6        |
# |Musapet               |2020|1092.0        |
# |Amangal               |22  |1089.8        |
# |Chandampet            |2018|1086.5        |
# |Kondapur              |22  |1084.7        |
# |Muduchinthalapally    |22  |1079.5        |
# |Quthbullapur          |22  |1079.1        |
# |Pebbair               |2020|1079.1        |
# |Chilipched            |2020|1076.2        |
# |Kattangoor            |2018|1075.5        |
# |Nizamabad South       |2018|1070.6        |
# |Bhongir               |2018|1068.2        |
# |Manopad               |2020|1067.3        |
# |Thungathurthi         |22  |1062.2        |
# |Medchel               |21  |1061.4        |
# |Hathanoora            |22  |1059.7        |
# |Marpalle              |21  |1056.0        |
# |Kethepalle            |21  |1055.6        |
# |Miryalaguda           |2018|1053.5        |
# |Atmakur_M             |21  |1051.4        |
# |Jharasangam           |2020|1050.0        |
# |Munagala              |21  |1049.2        |
# |Maganoor              |2020|1048.1        |
# |Tirumalgiri           |22  |1047.6        |
# |Marriguda             |21  |1046.8        |
# |Shabad                |21  |1046.4        |
# |Devarakonda           |2018|1045.0        |
# |Peddakothapalle       |2020|1044.8        |
# |Ghatkesar             |21  |1037.6        |
# |Chinna_Chintha_Kunta  |2020|1037.1        |
# +----------------------+----+--------------+
# only showing top 500 rows
#
# Average for JUL across all district:
# +--------+--------+--------+--------+---------+---------+--------+
# |avg_tmax|avg_tmin|avg_hmax|avg_hmin|avg_WSmax|avg_WSmin|avg_rain|
# +--------+--------+--------+--------+---------+---------+--------+
# |32.3    |24.66   |91.47   |65.24   |11.65    |0.83     |6.41    |
# +--------+--------+--------+--------+---------+---------+--------+
#
# Average for MAY across all district:
# +--------+--------+--------+--------+---------+---------+--------+
# |avg_tmax|avg_tmin|avg_hmax|avg_hmin|avg_WSmax|avg_WSmin|avg_rain|
# +--------+--------+--------+--------+---------+---------+--------+
# |41.09   |27.69   |65.22   |23.84   |11.2     |0.22     |0.68    |
# +--------+--------+--------+--------+---------+---------+--------+
#
# Best and worst year of temperature for JUL:
# +----+------------+
# |year|JUL_temp_max|
# +----+------------+
# |2018|       31.56|
# +----+------------+
#
# +----+------------+
# |year|JUL_temp_min|
# +----+------------+
# |2018|       24.54|
# +----+------------+
#
# Best and worst year of humidity for JUL:
# +----+----------------+
# |year|JUL_humidity_max|
# +----+----------------+
# |2018|           88.43|
# +----+----------------+
#
# +----+----------------+
# |year|JUL_humidity_min|
# +----+----------------+
# |2018|           64.55|
# +----+----------------+
#
# Best and worst year of wind speed for JUL:
# +----+------------------+
# |year|JUL_wind_speed_max|
# +----+------------------+
# |2018|              12.6|
# +----+------------------+
#
# +----+------------------+
# |year|JUL_wind_speed_min|
# +----+------------------+
# |2018|              1.03|
# +----+------------------+
#
# Best and worst year of rainfall for JUL:
# +----+------------+
# |year|may_rain_max|
# +----+------------+
# |2018|        4.99|
# +----+------------+
#
# +----+------------+
# |year|may_rain_min|
# +----+------------+
# |2018|        4.99|
# +----+------------+
#
# Best and worst year of temperature for SEPT:
# +----+-------------+
# |year|SEPT_temp_max|
# +----+-------------+
# |2018|        33.27|
# +----+-------------+
#
# +----+-------------+
# |year|SEPT_temp_min|
# +----+-------------+
# |2018|        23.55|
# +----+-------------+
#
# Best and worst year of humidity for SEPT:
# +----+-----------------+
# |year|SEPT_humidity_max|
# +----+-----------------+
# |2018|             91.4|
# +----+-----------------+
#
# +----+-----------------+
# |year|SEPT_humidity_min|
# +----+-----------------+
# |2018|            56.81|
# +----+-----------------+
#
# Best and worst year of wind speed for SEPT:
# +----+-------------------+
# |year|SEPT_wind_speed_max|
# +----+-------------------+
# |2018|               8.87|
# +----+-------------------+
#
# +----+-------------------+
# |year|SEPT_wind_speed_min|
# +----+-------------------+
# |2018|               0.09|
# +----+-------------------+
#
# Best and worst year of rainfall for SEPT:
# +----+------------+
# |year|may_rain_max|
# +----+------------+
# |2018|        2.68|
# +----+------------+
#
# +----+------------+
# |year|may_rain_min|
# +----+------------+
# |2018|        2.68|
# +----+------------+
#
# Program duration: 55.23721578000004s
